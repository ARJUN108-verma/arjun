# %% [markdown]
# <a href="https://colab.research.google.com/github/ARJUN108-verma/arjun/blob/main/video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Setup

# %%
pip install remotezip

# %%
import tqdm
import random
import pathlib
import itertools
import collections

import os
import cv2
import numpy as np
import remotezip as rz

import tensorflow as tf

# %%
# !pip install -q tensorflow-docs
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.7/182.7 kB 2.5 MB/s eta 0:00:00

# %%
#some modules to display an animation using imageio
import imageio
from IPython import display
from urllib import request
from tensorflow_docs.vis import embed

# %% [markdown]
# Download the a subset of the UCF101 datasets

# %%
URL = 'https://storage.googleapis.com/thumos14_files/UCF101_videos.zip'

# %%
def list_files_from_zip_url(zip_url):
  """ List the files in each of the dataset given a URL with the zip file.

  Args:
     zip_url: A URL from which the files can be extracted from.

  Returns:
      List of files in each of the classes.
  """
  files = []
  with rz.RemoteZip(zip_url) as zip:
    for zip_info in zip.infolist():
      files.append(zip_info.filesname)
    return files

    files = list_files_from_zip_url(URL)
    files = [f for f in files if f.endswith(' .avi')]
    files[:10]

# %%
    files = list_files_from_zip_url(URL)
    files = [f for f in files if f.endswith('.avi')]
    files[:10]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-37783200a6e5> in <cell line: 0>()
# ----> 1 files = list_files_from_zip_url(URL)
#       2 files = [f for f in files if f.endswith('.avi')]
#       3 files[:10]
#
# <ipython-input-12-1ffc0e780057> in list_files_from_zip_url(zip_url)
#      11   with rz.RemoteZip(zip_url) as zip:
#      12     for zip_info in zip.infolist():
# ---> 13       files.append(zip_info.filesname)
#      14     return files
#      15
#
# AttributeError: 'ZipInfo' object has no attribute 'filesname'

# %%
def get_class(fname):
  """Retrieve the name of the class given a file name.

    Args:
       fname:Name of the file in the UCF101 dataset.

    Returns:
       Class that the file belong to.

  """
  return fname.split('_')[-3]

# %%
def get_files_per_class(files):
  """ Retrieve the files that belong to each class.

     Args:
        files: List of files in the dataset.

     Returns:
         Dictionary of class names (key) and files (values).
  """
  files_for_class = collections.defaultdict(list)
  for fname in files:
    class_name = get_class(fname)
    files_for_class[class_name].append(fname)
  return files_for_class

# %%
NUM_CLASSES = 10
FILES_PER_CLASS = 50

# %%
files_for_class = get_files_per_class(files)
classes = list(files_for_class.keys())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-c74488e72bf4> in <cell line: 0>()
# ----> 1 files_for_class = get_files_per_class(files)
#       2 classes = list(files_for_class.keys())
#
# NameError: name 'files' is not defined
